# %%
1+1
# Out:
# 2

# %%
include("src/gravlens.jl")
# Out:
# WARNING: Method definition H(Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/cosmology.jl:18 overwritten at /Users/ariel/Desktop/GRAVLENS/src/cosmology.jl:18.
# WARNING: Method definition OM(Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/cosmology.jl:21 overwritten at /Users/ariel/Desktop/GRAVLENS/src/cosmology.jl:21.
# WARNING: Method definition OL(Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/cosmology.jl:22 overwritten at /Users/ariel/Desktop/GRAVLENS/src/cosmology.jl:22.
# WARNING: Method definition unnormalizedDa(Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/cosmology.jl:25 overwritten at /Users/ariel/Desktop/GRAVLENS/src/cosmology.jl:25.
# WARNING: Method definition D(Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/cosmology.jl:31 overwritten at /Users/ariel/Desktop/GRAVLENS/src/cosmology.jl:31.
# WARNING: Method definition D2(Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/cosmology.jl:32 overwritten at /Users/ariel/Desktop/GRAVLENS/src/cosmology.jl:32.
# WARNING: Method definition F(Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/cosmology.jl:34 overwritten at /Users/ariel/Desktop/GRAVLENS/src/cosmology.jl:34.
# WARNING: Method definition F2(Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/cosmology.jl:35 overwritten at /Users/ariel/Desktop/GRAVLENS/src/cosmology.jl:35.
# WARNING: Method definition ρc(Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/cosmology.jl:38 overwritten at /Users/ariel/Desktop/GRAVLENS/src/cosmology.jl:38.
# WARNING: Method definition A(Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/cosmology.jl:40 overwritten at /Users/ariel/Desktop/GRAVLENS/src/cosmology.jl:40.
# WARNING: Method definition ρ0(Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/cosmology.jl:42 overwritten at /Users/ariel/Desktop/GRAVLENS/src/cosmology.jl:42.
# WARNING: Method definition RXb(Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/cosmology.jl:44 overwritten at /Users/ariel/Desktop/GRAVLENS/src/cosmology.jl:44.
# WARNING: Method definition R200b(Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/cosmology.jl:47 overwritten at /Users/ariel/Desktop/GRAVLENS/src/cosmology.jl:47.
# WARNING: Method definition RXc(Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/cosmology.jl:49 overwritten at /Users/ariel/Desktop/GRAVLENS/src/cosmology.jl:49.
# WARNING: Method definition R200c(Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/cosmology.jl:52 overwritten at /Users/ariel/Desktop/GRAVLENS/src/cosmology.jl:52.
# WARNING: Method definition RVIR(Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/cosmology.jl:54 overwritten at /Users/ariel/Desktop/GRAVLENS/src/cosmology.jl:54.
# WARNING: Method definition E(Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/cosmology.jl:58 overwritten at /Users/ariel/Desktop/GRAVLENS/src/cosmology.jl:58.
# WARNING: Method definition Dc(Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/cosmology.jl:60 overwritten at /Users/ariel/Desktop/GRAVLENS/src/cosmology.jl:60.
# WARNING: Method definition rad_to_as(Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/cosmology.jl:63 overwritten at /Users/ariel/Desktop/GRAVLENS/src/cosmology.jl:63.
# WARNING: Method definition as_to_rad(Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/cosmology.jl:64 overwritten at /Users/ariel/Desktop/GRAVLENS/src/cosmology.jl:64.
# WARNING: Method definition Da_rad(Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/cosmology.jl:65 overwritten at /Users/ariel/Desktop/GRAVLENS/src/cosmology.jl:65.
# WARNING: Method definition Da_as(Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/cosmology.jl:66 overwritten at /Users/ariel/Desktop/GRAVLENS/src/cosmology.jl:66.
# WARNING: Method definition Δcvir(Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/cosmology.jl:71 overwritten at /Users/ariel/Desktop/GRAVLENS/src/cosmology.jl:71.
# WARNING: Method definition rg(Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/rays.jl:1 overwritten at /Users/ariel/Desktop/GRAVLENS/src/rays.jl:1.
# WARNING: Method definition dudθ(Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/rays.jl:4 overwritten at /Users/ariel/Desktop/GRAVLENS/src/rays.jl:4.
# WARNING: Method definition dduddθ(Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/rays.jl:10 overwritten at /Users/ariel/Desktop/GRAVLENS/src/rays.jl:10.
# WARNING: Method definition ray_angle(Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/rays.jl:28 overwritten at /Users/ariel/Desktop/GRAVLENS/src/rays.jl:28.
# WARNING: Method definition mylinspace(Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/rays.jl:35 overwritten at /Users/ariel/Desktop/GRAVLENS/src/rays.jl:35.
# WARNING: Method definition extrapolate_to_meeting(Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/rays.jl:42 overwritten at /Users/ariel/Desktop/GRAVLENS/src/rays.jl:42.
# WARNING: Method definition to_small(Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/rays.jl:67 overwritten at /Users/ariel/Desktop/GRAVLENS/src/rays.jl:67.
# WARNING: Method definition projected_mass(Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/mass.jl:9 overwritten at /Users/ariel/Desktop/GRAVLENS/src/mass.jl:9.
# WARNING: Method definition cumulative_mass(Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/mass.jl:20 overwritten at /Users/ariel/Desktop/GRAVLENS/src/mass.jl:20.
# WARNING: Method definition tiso_ρ(Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/mass.jl:32 overwritten at /Users/ariel/Desktop/GRAVLENS/src/mass.jl:32.
# WARNING: Method definition tiso_m(Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/mass.jl:39 overwritten at /Users/ariel/Desktop/GRAVLENS/src/mass.jl:39.
# WARNING: Method definition tiso_mp(Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/mass.jl:43 overwritten at /Users/ariel/Desktop/GRAVLENS/src/mass.jl:43.
# WARNING: Method definition tnfw_ρ(Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/mass.jl:53 overwritten at /Users/ariel/Desktop/GRAVLENS/src/mass.jl:53.
# WARNING: Method definition tnfw_m(Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/mass.jl:65 overwritten at /Users/ariel/Desktop/GRAVLENS/src/mass.jl:65.
# WARNING: Method definition tnfw_mp(Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/mass.jl:75 overwritten at /Users/ariel/Desktop/GRAVLENS/src/mass.jl:75.
# WARNING: Method definition lnfw_ρ(Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/mass.jl:85 overwritten at /Users/ariel/Desktop/GRAVLENS/src/mass.jl:85.
# WARNING: Method definition lnfw_m(Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/mass.jl:92 overwritten at /Users/ariel/Desktop/GRAVLENS/src/mass.jl:92.
# WARNING: Method definition lnfw_mp(Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/mass.jl:95 overwritten at /Users/ariel/Desktop/GRAVLENS/src/mass.jl:95.
# WARNING: Method definition vnfw_ρ(Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/mass.jl:105 overwritten at /Users/ariel/Desktop/GRAVLENS/src/mass.jl:105.
# WARNING: Method definition #vnfw_ρ(Array{Any, 1}, Main.#vnfw_ρ, Any, Any, Any, Any) in module Main overwritten.
# WARNING: Method definition vnfw_m(Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/mass.jl:112 overwritten at /Users/ariel/Desktop/GRAVLENS/src/mass.jl:112.
# WARNING: Method definition #vnfw_m(Array{Any, 1}, Main.#vnfw_m, Any, Any, Any, Any) in module Main overwritten.
# WARNING: Method definition vnfw_mp(Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/mass.jl:115 overwritten at /Users/ariel/Desktop/GRAVLENS/src/mass.jl:115.
# WARNING: Method definition #vnfw_mp(Array{Any, 1}, Main.#vnfw_mp, Any, Any, Any, Any) in module Main overwritten.
# WARNING: Method definition harmonic(Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/harmonic.jl:3 overwritten at /Users/ariel/Desktop/GRAVLENS/src/harmonic.jl:3.
# WARNING: Method definition harmonic(Any, Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/harmonic.jl:3 overwritten at /Users/ariel/Desktop/GRAVLENS/src/harmonic.jl:3.
# WARNING: Method definition harmonic200b(Any, Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/harmonic.jl:32 overwritten at /Users/ariel/Desktop/GRAVLENS/src/harmonic.jl:32.
# WARNING: Method definition harmonic200c(Any, Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/harmonic.jl:34 overwritten at /Users/ariel/Desktop/GRAVLENS/src/harmonic.jl:34.
# WARNING: Method definition harmonicVir(Any, Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/harmonic.jl:36 overwritten at /Users/ariel/Desktop/GRAVLENS/src/harmonic.jl:36.
# WARNING: Method definition harmonic_e(Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/harmonic.jl:40 overwritten at /Users/ariel/Desktop/GRAVLENS/src/harmonic.jl:40.
# WARNING: Method definition harmonic_e(Any, Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/harmonic.jl:40 overwritten at /Users/ariel/Desktop/GRAVLENS/src/harmonic.jl:40.
# WARNING: Method definition harmonic_e200b(Any, Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/harmonic.jl:72 overwritten at /Users/ariel/Desktop/GRAVLENS/src/harmonic.jl:72.
# WARNING: Method definition harmonic_e200c(Any, Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/harmonic.jl:74 overwritten at /Users/ariel/Desktop/GRAVLENS/src/harmonic.jl:74.
# WARNING: Method definition harmonic_eVir(Any, Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/harmonic.jl:76 overwritten at /Users/ariel/Desktop/GRAVLENS/src/harmonic.jl:76.
# WARNING: Method definition _numeric_f(Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:4 overwritten at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:4.
# WARNING: Method definition _numeric_f(Any, Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:4 overwritten at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:4.
# WARNING: Method definition #_numeric_f(Array{Any, 1}, Main.#_numeric_f, Any, Any, Any, Any) in module Main overwritten.
# WARNING: Method definition #_numeric_f(Array{Any, 1}, Main.#_numeric_f, Any, Any, Any, Any, Any) in module Main overwritten.
# WARNING: Method definition numeric(Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:31 overwritten at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:31.
# WARNING: Method definition numeric(Any, Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:31 overwritten at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:31.
# WARNING: Method definition #numeric(Array{Any, 1}, Main.#numeric, Any, Any, Any, Any) in module Main overwritten.
# WARNING: Method definition #numeric(Array{Any, 1}, Main.#numeric, Any, Any, Any, Any, Any) in module Main overwritten.
# WARNING: Method definition numeric_el(Any, Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:41 overwritten at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:41.
# WARNING: Method definition numeric_el(Any, Any, Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:41 overwritten at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:41.
# WARNING: Method definition #numeric_el(Array{Any, 1}, Main.#numeric_el, Any, Any, Any, Any, Any) in module Main overwritten.
# WARNING: Method definition #numeric_el(Array{Any, 1}, Main.#numeric_el, Any, Any, Any, Any, Any, Any) in module Main overwritten.
# WARNING: Method definition numeric_tiso200b(Any, Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:59 overwritten at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:59.
# WARNING: Method definition numeric_tiso200b(Any, Any, Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:59 overwritten at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:59.
# WARNING: Method definition #numeric_tiso200b(Array{Any, 1}, Main.#numeric_tiso200b, Any, Any, Any, Any, Any) in module Main overwritten.
# WARNING: Method definition #numeric_tiso200b(Array{Any, 1}, Main.#numeric_tiso200b, Any, Any, Any, Any, Any, Any) in module Main overwritten.
# WARNING: Method definition numeric_tiso200c(Any, Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:61 overwritten at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:61.
# WARNING: Method definition numeric_tiso200c(Any, Any, Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:61 overwritten at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:61.
# WARNING: Method definition #numeric_tiso200c(Array{Any, 1}, Main.#numeric_tiso200c, Any, Any, Any, Any, Any) in module Main overwritten.
# WARNING: Method definition #numeric_tiso200c(Array{Any, 1}, Main.#numeric_tiso200c, Any, Any, Any, Any, Any, Any) in module Main overwritten.
# WARNING: Method definition numeric_tiso_el200b(Any, Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:63 overwritten at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:63.
# WARNING: Method definition numeric_tiso_el200b(Any, Any, Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:63 overwritten at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:63.
# WARNING: Method definition #numeric_tiso_el200b(Array{Any, 1}, Main.#numeric_tiso_el200b, Any, Any, Any, Any, Any) in module Main overwritten.
# WARNING: Method definition #numeric_tiso_el200b(Array{Any, 1}, Main.#numeric_tiso_el200b, Any, Any, Any, Any, Any, Any) in module Main overwritten.
# WARNING: Method definition numeric_tiso_el200c(Any, Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:66 overwritten at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:66.
# WARNING: Method definition numeric_tiso_el200c(Any, Any, Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:66 overwritten at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:66.
# WARNING: Method definition #numeric_tiso_el200c(Array{Any, 1}, Main.#numeric_tiso_el200c, Any, Any, Any, Any, Any) in module Main overwritten.
# WARNING: Method definition #numeric_tiso_el200c(Array{Any, 1}, Main.#numeric_tiso_el200c, Any, Any, Any, Any, Any, Any) in module Main overwritten.
# WARNING: Method definition numeric_tisoVir(Any, Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:69 overwritten at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:69.
# WARNING: Method definition numeric_tisoVir(Any, Any, Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:69 overwritten at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:69.
# WARNING: Method definition #numeric_tisoVir(Array{Any, 1}, Main.#numeric_tisoVir, Any, Any, Any, Any, Any) in module Main overwritten.
# WARNING: Method definition #numeric_tisoVir(Array{Any, 1}, Main.#numeric_tisoVir, Any, Any, Any, Any, Any, Any) in module Main overwritten.
# WARNING: Method definition numeric_tiso_elVir(Any, Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:71 overwritten at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:71.
# WARNING: Method definition numeric_tiso_elVir(Any, Any, Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:71 overwritten at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:71.
# WARNING: Method definition #numeric_tiso_elVir(Array{Any, 1}, Main.#numeric_tiso_elVir, Any, Any, Any, Any, Any) in module Main overwritten.
# WARNING: Method definition #numeric_tiso_elVir(Array{Any, 1}, Main.#numeric_tiso_elVir, Any, Any, Any, Any, Any, Any) in module Main overwritten.
# WARNING: Method definition numeric_tnfw200b(Any, Any, Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:75 overwritten at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:75.
# WARNING: Method definition numeric_tnfw200b(Any, Any, Any, Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:75 overwritten at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:75.
# WARNING: Method definition #numeric_tnfw200b(Array{Any, 1}, Main.#numeric_tnfw200b, Any, Any, Any, Any, Any, Any) in module Main overwritten.
# WARNING: Method definition #numeric_tnfw200b(Array{Any, 1}, Main.#numeric_tnfw200b, Any, Any, Any, Any, Any, Any, Any) in module Main overwritten.
# WARNING: Method definition numeric_tnfw200c(Any, Any, Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:77 overwritten at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:77.
# WARNING: Method definition numeric_tnfw200c(Any, Any, Any, Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:77 overwritten at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:77.
# WARNING: Method definition #numeric_tnfw200c(Array{Any, 1}, Main.#numeric_tnfw200c, Any, Any, Any, Any, Any, Any) in module Main overwritten.
# WARNING: Method definition #numeric_tnfw200c(Array{Any, 1}, Main.#numeric_tnfw200c, Any, Any, Any, Any, Any, Any, Any) in module Main overwritten.
# WARNING: Method definition numeric_tnfw_el200b(Any, Any, Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:79 overwritten at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:79.
# WARNING: Method definition numeric_tnfw_el200b(Any, Any, Any, Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:79 overwritten at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:79.
# WARNING: Method definition #numeric_tnfw_el200b(Array{Any, 1}, Main.#numeric_tnfw_el200b, Any, Any, Any, Any, Any, Any) in module Main overwritten.
# WARNING: Method definition #numeric_tnfw_el200b(Array{Any, 1}, Main.#numeric_tnfw_el200b, Any, Any, Any, Any, Any, Any, Any) in module Main overwritten.
# WARNING: Method definition numeric_tnfw_el200c(Any, Any, Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:82 overwritten at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:82.
# WARNING: Method definition numeric_tnfw_el200c(Any, Any, Any, Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:82 overwritten at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:82.
# WARNING: Method definition #numeric_tnfw_el200c(Array{Any, 1}, Main.#numeric_tnfw_el200c, Any, Any, Any, Any, Any, Any) in module Main overwritten.
# WARNING: Method definition #numeric_tnfw_el200c(Array{Any, 1}, Main.#numeric_tnfw_el200c, Any, Any, Any, Any, Any, Any, Any) in module Main overwritten.
# WARNING: Method definition numeric_tnfwVir(Any, Any, Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:85 overwritten at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:85.
# WARNING: Method definition numeric_tnfwVir(Any, Any, Any, Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:85 overwritten at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:85.
# WARNING: Method definition #numeric_tnfwVir(Array{Any, 1}, Main.#numeric_tnfwVir, Any, Any, Any, Any, Any, Any) in module Main overwritten.
# WARNING: Method definition #numeric_tnfwVir(Array{Any, 1}, Main.#numeric_tnfwVir, Any, Any, Any, Any, Any, Any, Any) in module Main overwritten.
# WARNING: Method definition numeric_tnfw_elVir(Any, Any, Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:87 overwritten at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:87.
# WARNING: Method definition numeric_tnfw_elVir(Any, Any, Any, Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:87 overwritten at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:87.
# WARNING: Method definition #numeric_tnfw_elVir(Array{Any, 1}, Main.#numeric_tnfw_elVir, Any, Any, Any, Any, Any, Any) in module Main overwritten.
# WARNING: Method definition #numeric_tnfw_elVir(Array{Any, 1}, Main.#numeric_tnfw_elVir, Any, Any, Any, Any, Any, Any, Any) in module Main overwritten.
# WARNING: Method definition thin(Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/thin.jl:3 overwritten at /Users/ariel/Desktop/GRAVLENS/src/thin.jl:3.
# WARNING: Method definition thin(Any, Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/thin.jl:3 overwritten at /Users/ariel/Desktop/GRAVLENS/src/thin.jl:3.
# WARNING: Method definition thin_tiso200b(Any, Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/thin.jl:41 overwritten at /Users/ariel/Desktop/GRAVLENS/src/thin.jl:41.
# WARNING: Method definition thin_tiso200b(Any, Any, Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/thin.jl:41 overwritten at /Users/ariel/Desktop/GRAVLENS/src/thin.jl:41.
# WARNING: Method definition thin_tiso200c(Any, Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/thin.jl:43 overwritten at /Users/ariel/Desktop/GRAVLENS/src/thin.jl:43.
# WARNING: Method definition thin_tiso200c(Any, Any, Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/thin.jl:43 overwritten at /Users/ariel/Desktop/GRAVLENS/src/thin.jl:43.
# WARNING: Method definition thin_tisoVir(Any, Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/thin.jl:45 overwritten at /Users/ariel/Desktop/GRAVLENS/src/thin.jl:45.
# WARNING: Method definition thin_tisoVir(Any, Any, Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/thin.jl:45 overwritten at /Users/ariel/Desktop/GRAVLENS/src/thin.jl:45.
# WARNING: Method definition thin_tnfw200b(Any, Any, Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/thin.jl:48 overwritten at /Users/ariel/Desktop/GRAVLENS/src/thin.jl:48.
# WARNING: Method definition thin_tnfw200b(Any, Any, Any, Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/thin.jl:48 overwritten at /Users/ariel/Desktop/GRAVLENS/src/thin.jl:48.
# WARNING: Method definition thin_tnfw200c(Any, Any, Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/thin.jl:50 overwritten at /Users/ariel/Desktop/GRAVLENS/src/thin.jl:50.
# WARNING: Method definition thin_tnfw200c(Any, Any, Any, Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/thin.jl:50 overwritten at /Users/ariel/Desktop/GRAVLENS/src/thin.jl:50.
# WARNING: Method definition thin_tnfwVir(Any, Any, Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/thin.jl:52 overwritten at /Users/ariel/Desktop/GRAVLENS/src/thin.jl:52.
# WARNING: Method definition thin_tnfwVir(Any, Any, Any, Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/thin.jl:52 overwritten at /Users/ariel/Desktop/GRAVLENS/src/thin.jl:52.
# WARNING: Method definition time(Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/time.jl:3 overwritten at /Users/ariel/Desktop/GRAVLENS/src/time.jl:3.
# WARNING: Method definition get_delay_hrs(Any, Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/precision.jl:2 overwritten at /Users/ariel/Desktop/GRAVLENS/src/precision.jl:2.
# WARNING: Method definition get_delay_hrs(Any, Any, Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/precision.jl:2 overwritten at /Users/ariel/Desktop/GRAVLENS/src/precision.jl:2.

# %%
hx, hy, hu, hdu, hia, hoa, hda, hθ =
    harmonic200c(1.0, 200.0, pi/58, 0.0000001, 10000);
dx, dy, du, ddu, dia, doa, dda, dθ =
    numeric_tiso200c(1.0, 200.0, π/58, R200c(1.0, 200.0), 0.0000001, 10000);
tx, ty, tu, tdu, tia, toa, tda, tθ =
    thin_tiso200c(1.0, 200.0, π/58, R200c(1.0, 200.0), 0.0000001, 10000);

# %%
ixs = find((hx.>-300).*(hx.<300))
hx=hx[ixs]
hy=hy[ixs]
plot(dx, dy, "-y", lw=3.3)
hold(true)
plot(hx, hy, "-k")
plot(tx, ty, "-r", lw=0.9)
x0 = cos(pi/6)*R200c(1.0,200)
y0 = sin(pi/6)*R200c(1.0,200)
plot([-x0, x0], [y0, y0+0.000001*2x0],"--k")
xlim(minimum(hx)*1.05, maximum(hx)*1.05)
ylim(minimum(hy)*0.9999996, maximum(hy)*1.000002)
grid(true)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x315b7f290>)

# %%
rs = 3.3e6
b = 4

tg = b/rs
dx, dy, du, ddu, dia, doa, dda, dθ =
    numeric_tiso200c(0.5, 200.0, 0.0, rs, tg, 100000);

spl = Spline1D(dθ, du, k=4);
@show θ0 = fzero(t->evaluate(spl,t)-1.0/R200c(0.5,200.0) , 0.02)

spl = Spline1D(dθ, ddu, k=4);
tgα0 = tan(ray_angle(θ0, R200c(0.5,200.0), evaluate(spl, θ0)))

hx, hy, hu, hdu, hia, hoa, hda, hθ =
    harmonic200c(0.5, 200.0, θ0, tgα0, 100000);
tx, ty, tu, tdu, tia, toa, tda, tθ =
    thin_tiso200c(0.5, 200.0, 0.0, rs, tg, 100000);
ex, ey, eu, edu, eia, eoa, eda, eθ =
    numeric_tiso_el200c(0.5, 200.0, 0.0, rs, tg, 100000, reltol=1.0e-14, abstol=1.0e-15);

ix=find(eu.==maximum(eu))[1]
x=ex[ix]
y=ey[ix]
rmin=sqrt(x*x+y*y)

hex, hey, heu, heθ, heia =
    harmonic_e(200.0, rmin, tgα0, R200c(0.5,200), 100000);
# Out:
# θ0 = fzero((t->begin  # In[9], line 9:
#                 evaluate(spl,t) - 1.0 / R200c(0.5,200.0)
#             end),0.02) = 0.02330576096188824
# dα = (π / 2 + a1) - a2 = 1.5707972913224653
# dα - π / 2 = 9.64527568703133e-7

# %%
plot(dx/1e3, dy, "-y",lw=3.3)
hold(true)
plot(tx/1e3, ty, "-r",lw=0.9)
plot(ex/1e3, ey, "-g",lw=0.9)
plot(hx/1e3, hy, "-k",lw=0.9)
plot(hex/1e3, hey, ":b",lw=3.5)
legend(["numeric","thin","numeric+el"], loc=3)
grid(true)
xlabel("X [Mpc/h]")
ylabel("Y [Kpc/h]")
r=R200c(0.5,200)
x=cos(linspace(0,2π,500)).*r
y=sin(linspace(0,2π,500)).*r
plot(x/1e3,y,"-c")
xlim(-0.3,0.3)
ylim(3.9994,4.00005)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x315fc0e90>)
# (3.9994,4.00005)

# %%
plot(dx/1e3, dy, "-y",lw=3.3)
hold(true)
plot(tx/1e3, ty, "-r",lw=0.9)
plot(ex/1e3, ey, "-g",lw=0.9)
plot(hx/1e3, hy, "-k",lw=0.9)
plot(hex/1e3,hey,":b",lw=3.5)
legend(["numeric","thin","numeric+el","harmonic","approx_el"], loc=2)
grid(true)
xlabel("X [Mpc/h]")
ylabel("Y [Kpc/h]")
xlim(-0.07,0.07)
ylim(3.9999,4.00001)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x3162d2750>)
# (3.9999,4.00001)

# %%
bs=Float64[]
tdas=Float64[]
ddas=Float64[]
edas=Float64[]

rs = 3.3e6
for b in linspace(1, 500, 150)
    push!(bs, b)

    tg = b/rs
    dx, dy, du, ddu, dia, doa, dda, dθ =
        numeric_tiso200c(0.5, 500.0, 0.0, rs, tg, 100);
    tx, ty, tu, tdu, tia, toa, tda, tθ =
        thin_tiso200c(0.5, 500.0, 0.0, rs, tg, 100);
    ex, ey, eu, edu, eia, eoa, eda, eθ =
    numeric_tiso_el200c(0.5, 500.0, 0.0, rs, tg, 100);
    
    push!(tdas, tda)
    push!(ddas, dda)
    push!(edas, eda);
end;

plot(bs, ddas*1e6, "-y", lw=3.3)
hold(true)
plot(bs, tdas*1e6, "-r", lw=2.1)
plot(bs, edas*1e6, "-g", lw=0.9)
r=R200c(0.5,500.0)
plot([r,r],[0,1e7],"--k")
ylim(1e6*minimum(tdas), 1e6*maximum(edas))
grid(true)
xlabel("Impact parameter b [Kpc/h]")
ylabel("Deflection angle x 10^6")
legend(["Numeric","Thin","Numeric+el","halo R"])
title("deflection angles vs impact")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x3162d2410>)
# PyObject <matplotlib.text.Text object at 0x3156ea390>

# %%
bs=Float64[]
tdas=Float64[]
ddas=Float64[]
edas=Float64[]

rs = 3.3e6
for b in exp(linspace(log(0.01), log(500), 250))
    push!(bs, b)

    tg = b/rs
    dx, dy, du, ddu, dia, doa, dda, dθ =
    numeric_tnfw200c(0.5, 500.0, 10.0, 0.0, rs, tg, 100);
    tx, ty, tu, tdu, tia, toa, tda, tθ =
    thin_tnfw200c(0.5, 500.0, 10.0, 0.0, rs, tg, 100);
    ex, ey, eu, edu, eia, eoa, eda, eθ =
    numeric_tnfw_el200c(0.5, 500.0, 10.0, 0.0, rs, tg, 100);
    
    push!(tdas, tda)
    push!(ddas, dda)
    push!(edas, eda);
end;

# %%
plot(bs, ddas*1e6, "-y", lw=3.3)
hold(true)
plot(bs, tdas*1e6, "-r", lw=2.1)
plot(bs, edas*1e6, "-g", lw=0.9)
r=R200c(0.5,500.0)
plot([r,r],[0,1e7],"--k")
plot([10.0,10.0],[0,1e7],"--k")
#ylim(1e6*minimum(tdas), 1e6*maximum(edas))
ylim(0,18)
grid(true)
xlabel("Impact parameter b [Kpc/h]")
ylabel("Deflection angle x 10^6")
legend(["Numeric","Thin","Numeric+el","halo R"])
title("deflection angles vs impact")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x315dab990>)
# PyObject <matplotlib.text.Text object at 0x316032410>

# %%
plot(bs, edas./tdas,"-b")
hold(true)

r = R200c(0.5, 500.0)
plot([r,r],[0.8,2.4],"--k")
plot([10.0,10.0],[0.8,2.4],"-k")
grid(true)
xlabel("impact parameter b [Kpc/h]")
ylabel("numerical_el deflection / other deflections")
legend(["thin approximation","numeric, no el","halo R","NFW Rs"], loc=1)
title("ratio of deflection angles vs impact (NFW)")
ylim(1.0, 1.4)
xlim(0,350)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x315fa8310>)
# (0,350)

# %% [markdown]
# # Time

# %%
const r200 = R200c(0.5,500.0)
massfunc(r) = tnfw_m(500.0, 10.0, r, r200)
projmass(r) = tnfw_mp(500.0, 10.0, r, r200)
rhofunc(r) = tnfw_ρ(500.0, 10.0, r, r200)

b = 8.0;
rs = 1.3e6;
tg = b/rs
f = 0.85
up_dx, up_dy, up_du, up_ddu, up_dia, up_doa, up_dda, up_dθ =
    numeric(massfunc, 0.0, rs, tg, 100000);
up_tx, up_ty, up_tu, up_tdu, up_tia, up_toa, up_tda, tθ =
thin(projmass, 0.0, rs*f, tg, 100000);
up_ex, up_ey, up_eu, up_edu, up_eia, up_eoa, up_eda, up_eθ =
    numeric_el(massfunc, rhofunc, 0.0, rs, tg, 100000);

b = 11.0;
rs = 1.3e6;
tg = b/rs
down_dx, down_dy, down_du, down_ddu, down_dia, down_doa, down_dda, down_dθ =
    numeric(massfunc, 0.0, rs, tg, 100000);
down_tx, down_ty, down_tu, down_tdu, down_tia, down_toa, down_tda, down_tθ =
    thin(projmass, 0.0, rs*f, tg, 100000);
down_ex, down_ey, down_eu, down_edu, down_eia, down_eoa, down_eda, down_eθ =
    numeric_el(massfunc, rhofunc, 0.0, rs, tg, 100000);

utx,uty,dtx,dty = extrapolate_to_meeting(up_tx,up_ty,down_tx,down_ty);
udx,udy,ddx,ddy = extrapolate_to_meeting(up_dx,up_dy,down_dx,down_dy);
uex,uey,dex,dey = extrapolate_to_meeting(up_ex,up_ey,down_ex,down_ey);

# %%
hold(false)
plot(utx/1e3,uty,"-r",lw=0.9,label="thin")
hold(true)
plot(dtx/1e3,-dty,"-r",lw=0.9)
#plot(udx/1e3,udy,"-y",lw=0.9)
#plot(ddx/1e3,-ddy,"-y",lw=0.9)
plot(uex/1e3,uey,"-g",lw=0.9, label="numeric+el")
plot(dex/1e3,-dey,"-g",lw=0.9)
plot([0,0],[-8,4],"--k", label="lens plane")
plot([uex[1]/1e3],[uey[1]],"og",label="numeric+el observer")
plot([utx[1]/1e3],[uty[1]],"or",label="thin observer")

plot([uex[end]/1e3],[uey[end]],"*g",ms=7, label="numeric+el source")
plot([utx[end]/1e3],[uty[end]],"*r",ms=7, label="thin source")

hold(false)
grid(true)
xlabel("X [Mpc/h]")
ylabel("Y [Kpc/h]")
#legend(["thin","", "numeric+el","", "lens plane"], loc=3)
legend(loc=3)
title("two configurations satisfying observations (angle+time delay)")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x315c7ba90>)
# PyObject <matplotlib.text.Text object at 0x316450850>

# %%
udt = time(massfunc, udx, udy);
ddt = time(massfunc, ddx, ddy);
delta_d = abs(udt-ddt);
utt = time(massfunc, utx, uty);
dtt = time(massfunc, dtx, dty);
delta_t = abs(utt-dtt);
uet = time(massfunc, uex, uey);
det = time(massfunc, dex, dey);
delta_e = abs(uet-det);
@show delta_t;
@show delta_d;
@show delta_e;
# Out:
# delta_t = 2.7251090273239242e-11
# delta_d = 3.54631879417866e-11
# delta_e = 2.6997959423624707e-11

# %% [markdown]
# # Time 2

# %%
setprecision(128)
b = big"3.0";
rs = big"3.3e6";
tg = b/rs
f = 1.12
up_tx, up_ty, up_tu, up_tdu, up_tia, up_toa, up_tda, tθ =
thin(r->projmass(r)*f, 0.0, rs, tg, 100000);
up_ex, up_ey, up_eu, up_edu, up_eia, up_eoa, up_eda, up_eθ =
    numeric_el(massfunc, rhofunc, 0.0, rs, tg, 100000);

b = big"7.0";
rs = big"3.3e6";
tg = b/rs
down_tx, down_ty, down_tu, down_tdu, down_tia, down_toa, down_tda, down_tθ =
thin(r->projmass(r)*f, 0.0, rs, tg, 100000);
down_ex, down_ey, down_eu, down_edu, down_eia, down_eoa, down_eda, down_eθ =
    numeric_el(massfunc, rhofunc, 0.0, rs, tg, 100000);

# %%
utx,uty,dtx,dty = extrapolate_to_meeting(up_tx,up_ty,down_tx,down_ty);
uex,uey,dex,dey = extrapolate_to_meeting(up_ex,up_ey,down_ex,down_ey);

# %%
utt = time(r->massfunc(r)*f, utx, uty);
dtt = time(r->massfunc(r)*f, dtx, dty);
delta_t = abs(utt-dtt);
uet = time(massfunc, uex, uey);
det = time(massfunc, dex, dey);
delta_e = abs(uet-det);
@show delta_t;
@show delta_e;
# Out:
# delta_t = 8.411582541612006e-11
# delta_e = 8.655500777574069008250856729824703742432e-11

# %%
dtx = to_small(dtx)
dty = to_small(dty)
utx = to_small(utx)
uty = to_small(uty)

dex = to_small(dex)
dey = to_small(dey)
uex = to_small(uex)
uey = to_small(uey)

hold(false)
plot(utx/1e3,uty,"-r",lw=0.9,label="thin")
hold(true)
plot(dtx/1e3,-dty,"-r",lw=0.9)
plot(uex/1e3,uey,"-g",lw=0.9, label="numeric+el")
plot(dex/1e3,-dey,"-g",lw=0.9)
plot([0,0],[-8,4],"--k", label="lens plane")
plot([uex[1]/1e3],[uey[1]],"og",label="numeric+el observer")
plot([utx[1]/1e3],[uty[1]],"or",label="thin observer")

plot([uex[end]/1e3],[uey[end]],"*g",ms=7, label="numeric+el source")
plot([utx[end]/1e3],[uty[end]],"*r",ms=7, label="thin source")

hold(false)
grid(true)
xlabel("X [Mpc/h]")
ylabel("Y [Kpc/h]")
#legend(["thin","", "numeric+el","", "lens plane"], loc=3)
legend(loc=3)
title("two configurations satisfying observations (angle+time delay)")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x3156c9a90>)
# PyObject <matplotlib.text.Text object at 0x3168863d0>

# %% [markdown]
# # Precision test

# %%
for prec in [1.0e-8, 1.0e-12, 1.0e-16, 1.0e-20]
    get_delay_hrs(128, big"3.0", big"7.01", big"3.3e6", prec);
    get_delay_hrs(128, big"3.0", big"0.01", big"3.3e6", prec);
end;
# Out:
# "128, 7.009999999999999999999999999999999999992, 9.026794308431694465937683715931632089449e-11"
# "128, 1.000000000000000000000000000000000000001e-02, 1.294067945966521968074101138740261587744e-12"
# "128, 7.009999999999999999999999999999999999992, 9.026794308431694465937683715931632089449e-11"
# "128, 1.000000000000000000000000000000000000001e-02, 1.294067945966521968074101138740261587744e-12"
# "128, 7.009999999999999999999999999999999999992, 9.026794308431694465937683715931632089449e-11"
# "128, 1.000000000000000000000000000000000000001e-02, 1.294067945966521968074101138740261587744e-12"
# "128, 7.009999999999999999999999999999999999992, 9.026794308431694465937683715931632089449e-11"
# "128, 1.000000000000000000000000000000000000001e-02, 1.294067945966521968074101138740261587744e-12"

# %% [markdown]
# # A370

# %%
r200 = R200c(0.375, 2.58e4)
# Out:
# WARNING: redefining constant r200
# 910.0471407539828

# %%
c200 = 6.37
RS=r200/c200
# Out:
# 142.86454328947926

# %%
b=Da_as(0.375, 43)
# Out:
# 155.5922223339736

# %%
rs=Dc(1.5)-Dc(0.375)
# Out:
# 2.0395800769630712e6

# %%
ro=Dc(0.375)
# Out:
# 1.0262369974909527e6

# %%
_m(r) = tnfw_m(2.58e4, RS, r, r200);
_pm(r) = tnfw_mp(2.58e4, RS, r, r200);
_rho(r) = tnfw_ρ(2.58e4, RS, r, r200);
# Out:
# WARNING: Method definition _m(Any) in module Main at In[37]:1 overwritten at In[38]:1.
# WARNING: Method definition _pm(Any) in module Main at In[37]:2 overwritten at In[38]:2.
# WARNING: Method definition _rho(Any) in module Main at In[37]:3 overwritten at In[38]:3.

# %%
mass_fac = 0.83 # 1.69
rs_fac   = 1.5

@show fmass = 2.58e4*mass_fac
@show frs = R200c(0.375, fmass)/c200*rs_fac

tg = b/rs
tx, ty, tu, tdu, tia, toa, tda, tθ =
    thin(_pm, 0.0, rs, tg, 100000);
ex, ey, eu, edu, eia, eoa, eda, eθ =
numeric_el(r->tnfw_m(fmass, frs, r, R200c(0.375,fmass)), r->tnfw_ρ(fmass, frs, r, R200c(0.375,fmass)), 0.0, rs, tg, 100000);
hold(false)
plot(tx,ty,"-r",lw=0.9)
hold(true)
plot(ex,ey,"-g",lw=1.1)
hold(false)
xlim(-rs,rs/2)
ylim(0, 1.5b)
grid(true)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x315dfb790>)
# fmass = 25800.0mass_fac = 21414.0
# frs = (R200c(0.375,fmass) / c200) * rs_fac = 201.39178305527705
