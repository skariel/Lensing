# %%
1+1
# Out:
# 2

# %%
include("src/gravlens.jl")
# Out:
# WARNING: Method definition Ha(Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/cosmology.jl:30 overwritten at /Users/ariel/Desktop/GRAVLENS/src/cosmology.jl:30.
# WARNING: Method definition FD(Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/cosmology.jl:33 overwritten at /Users/ariel/Desktop/GRAVLENS/src/cosmology.jl:33.
# WARNING: Method definition FK(Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/cosmology.jl:36 overwritten at /Users/ariel/Desktop/GRAVLENS/src/cosmology.jl:36.
# WARNING: Method definition OM(Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/cosmology.jl:42 overwritten at /Users/ariel/Desktop/GRAVLENS/src/cosmology.jl:42.
# WARNING: Method definition OL(Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/cosmology.jl:43 overwritten at /Users/ariel/Desktop/GRAVLENS/src/cosmology.jl:43.
# WARNING: Method definition unnormalizedD(Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/cosmology.jl:46 overwritten at /Users/ariel/Desktop/GRAVLENS/src/cosmology.jl:46.
# WARNING: Method definition D(Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/cosmology.jl:52 overwritten at /Users/ariel/Desktop/GRAVLENS/src/cosmology.jl:52.
# WARNING: Method definition D2(Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/cosmology.jl:53 overwritten at /Users/ariel/Desktop/GRAVLENS/src/cosmology.jl:53.
# WARNING: Method definition F(Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/cosmology.jl:55 overwritten at /Users/ariel/Desktop/GRAVLENS/src/cosmology.jl:55.
# WARNING: Method definition F2(Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/cosmology.jl:56 overwritten at /Users/ariel/Desktop/GRAVLENS/src/cosmology.jl:56.
# WARNING: Method definition Z(Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/cosmology.jl:59 overwritten at /Users/ariel/Desktop/GRAVLENS/src/cosmology.jl:59.
# WARNING: Method definition ρ0(Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/cosmology.jl:60 overwritten at /Users/ariel/Desktop/GRAVLENS/src/cosmology.jl:60.
# WARNING: Method definition R200(Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/cosmology.jl:62 overwritten at /Users/ariel/Desktop/GRAVLENS/src/cosmology.jl:62.
# WARNING: Method definition rg(Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/rays.jl:1 overwritten at /Users/ariel/Desktop/GRAVLENS/src/rays.jl:1.
# WARNING: Method definition dudθ(Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/rays.jl:4 overwritten at /Users/ariel/Desktop/GRAVLENS/src/rays.jl:4.
# WARNING: Method definition dduddθ(Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/rays.jl:10 overwritten at /Users/ariel/Desktop/GRAVLENS/src/rays.jl:10.
# WARNING: Method definition ray_angle(Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/rays.jl:28 overwritten at /Users/ariel/Desktop/GRAVLENS/src/rays.jl:28.
# WARNING: Method definition mylinspace(Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/rays.jl:35 overwritten at /Users/ariel/Desktop/GRAVLENS/src/rays.jl:35.
# WARNING: Method definition extrapolate_to_meeting(Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/rays.jl:42 overwritten at /Users/ariel/Desktop/GRAVLENS/src/rays.jl:42.
# WARNING: Method definition to_small(Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/rays.jl:67 overwritten at /Users/ariel/Desktop/GRAVLENS/src/rays.jl:67.
# WARNING: Method definition projected_mass(Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/mass.jl:9 overwritten at /Users/ariel/Desktop/GRAVLENS/src/mass.jl:9.
# WARNING: Method definition cumulative_mass(Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/mass.jl:20 overwritten at /Users/ariel/Desktop/GRAVLENS/src/mass.jl:20.
# WARNING: Method definition tiso_ρ(Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/mass.jl:32 overwritten at /Users/ariel/Desktop/GRAVLENS/src/mass.jl:32.
# WARNING: Method definition tiso_m(Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/mass.jl:39 overwritten at /Users/ariel/Desktop/GRAVLENS/src/mass.jl:39.
# WARNING: Method definition tiso_mp(Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/mass.jl:42 overwritten at /Users/ariel/Desktop/GRAVLENS/src/mass.jl:42.
# WARNING: Method definition tnfw_ρ(Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/mass.jl:52 overwritten at /Users/ariel/Desktop/GRAVLENS/src/mass.jl:52.
# WARNING: Method definition tnfw_m(Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/mass.jl:63 overwritten at /Users/ariel/Desktop/GRAVLENS/src/mass.jl:63.
# WARNING: Method definition tnfw_mp(Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/mass.jl:66 overwritten at /Users/ariel/Desktop/GRAVLENS/src/mass.jl:66.
# WARNING: Method definition lnfw_ρ(Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/mass.jl:76 overwritten at /Users/ariel/Desktop/GRAVLENS/src/mass.jl:76.
# WARNING: Method definition lnfw_m(Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/mass.jl:84 overwritten at /Users/ariel/Desktop/GRAVLENS/src/mass.jl:84.
# WARNING: Method definition lnfw_mp(Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/mass.jl:87 overwritten at /Users/ariel/Desktop/GRAVLENS/src/mass.jl:87.
# WARNING: Method definition harmonic(Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/harmonic.jl:3 overwritten at /Users/ariel/Desktop/GRAVLENS/src/harmonic.jl:3.
# WARNING: Method definition harmonic(Any, Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/harmonic.jl:3 overwritten at /Users/ariel/Desktop/GRAVLENS/src/harmonic.jl:3.
# WARNING: Method definition harmonic_e(Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/harmonic.jl:34 overwritten at /Users/ariel/Desktop/GRAVLENS/src/harmonic.jl:34.
# WARNING: Method definition harmonic_e(Any, Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/harmonic.jl:34 overwritten at /Users/ariel/Desktop/GRAVLENS/src/harmonic.jl:34.
# WARNING: Method definition _numeric_f(Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:4 overwritten at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:4.
# WARNING: Method definition _numeric_f(Any, Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:4 overwritten at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:4.
# WARNING: Method definition #_numeric_f(Array{Any, 1}, Main.#_numeric_f, Any, Any, Any, Any) in module Main overwritten.
# WARNING: Method definition #_numeric_f(Array{Any, 1}, Main.#_numeric_f, Any, Any, Any, Any, Any) in module Main overwritten.
# WARNING: Method definition numeric(Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:31 overwritten at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:31.
# WARNING: Method definition numeric(Any, Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:31 overwritten at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:31.
# WARNING: Method definition #numeric(Array{Any, 1}, Main.#numeric, Any, Any, Any, Any) in module Main overwritten.
# WARNING: Method definition #numeric(Array{Any, 1}, Main.#numeric, Any, Any, Any, Any, Any) in module Main overwritten.
# WARNING: Method definition numeric_el(Any, Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:41 overwritten at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:41.
# WARNING: Method definition numeric_el(Any, Any, Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:41 overwritten at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:41.
# WARNING: Method definition #numeric_el(Array{Any, 1}, Main.#numeric_el, Any, Any, Any, Any, Any) in module Main overwritten.
# WARNING: Method definition #numeric_el(Array{Any, 1}, Main.#numeric_el, Any, Any, Any, Any, Any, Any) in module Main overwritten.
# WARNING: Method definition numeric_tiso(Any, Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:57 overwritten at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:57.
# WARNING: Method definition numeric_tiso(Any, Any, Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:57 overwritten at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:57.
# WARNING: Method definition #numeric_tiso(Array{Any, 1}, Main.#numeric_tiso, Any, Any, Any, Any, Any) in module Main overwritten.
# WARNING: Method definition #numeric_tiso(Array{Any, 1}, Main.#numeric_tiso, Any, Any, Any, Any, Any, Any) in module Main overwritten.
# WARNING: Method definition numeric_tiso_el(Any, Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:60 overwritten at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:60.
# WARNING: Method definition numeric_tiso_el(Any, Any, Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:60 overwritten at /Users/ariel/Desktop/GRAVLENS/src/numeric.jl:60.
# WARNING: Method definition #numeric_tiso_el(Array{Any, 1}, Main.#numeric_tiso_el, Any, Any, Any, Any, Any) in module Main overwritten.
# WARNING: Method definition #numeric_tiso_el(Array{Any, 1}, Main.#numeric_tiso_el, Any, Any, Any, Any, Any, Any) in module Main overwritten.
# WARNING: Method definition thin(Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/thin.jl:3 overwritten at /Users/ariel/Desktop/GRAVLENS/src/thin.jl:3.
# WARNING: Method definition thin(Any, Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/thin.jl:3 overwritten at /Users/ariel/Desktop/GRAVLENS/src/thin.jl:3.
# WARNING: Method definition thin_tiso(Any, Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/thin.jl:39 overwritten at /Users/ariel/Desktop/GRAVLENS/src/thin.jl:39.
# WARNING: Method definition thin_tiso(Any, Any, Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/thin.jl:39 overwritten at /Users/ariel/Desktop/GRAVLENS/src/thin.jl:39.
# WARNING: Method definition time(Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/time.jl:3 overwritten at /Users/ariel/Desktop/GRAVLENS/src/time.jl:3.
# WARNING: Method definition get_delay_hrs(Any, Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/precision.jl:2 overwritten at /Users/ariel/Desktop/GRAVLENS/src/precision.jl:2.
# WARNING: Method definition get_delay_hrs(Any, Any, Any, Any, Any, Any) in module Main at /Users/ariel/Desktop/GRAVLENS/src/precision.jl:2 overwritten at /Users/ariel/Desktop/GRAVLENS/src/precision.jl:2.

# %%
tnfw_m(0.5, 200.0, 10.0, R200(0.5,200.0))
# Out:
# 200.0

# %%
lnfw_m(0.5, 200.0, 10.0, 10*R200(0.5,200.0))
# Out:
# 199.74554347851787

# %%
hx, hy, hu, hdu, hia, hoa, hda, hθ =
    harmonic(0.5, 200.0, pi/58, 0.0000001, 10000);
dx, dy, du, ddu, dia, doa, dda, dθ =
    numeric_tiso(0.5, 200.0, π/58, R200(0.5, 200.0), 0.0000001, 10000);
tx, ty, tu, tdu, tia, toa, tda, tθ =
    thin_tiso(0.5, 200.0, π/58, R200(0.5, 200.0), 0.0000001, 10000);

# %%
ixs = find((hx.>-300).*(hx.<300))
hx=hx[ixs]
hy=hy[ixs]
plot(dx, dy, "-y", lw=3.3)
hold(true)
plot(hx, hy, "-k")
plot(tx, ty, "-r", lw=0.9)
x0 = cos(pi/6)*R200(1.0,200)
y0 = sin(pi/6)*R200(1.0,200)
plot([-x0, x0], [y0, y0+0.000001*2x0],"--k")
xlim(minimum(hx)*1.05, maximum(hx)*1.05)
ylim(minimum(hy)*0.9999996, maximum(hy)*1.000002)
grid(true)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x319f13e50>)

# %%
rs = 3.3e6
b = 4

tg = b/rs
dx, dy, du, ddu, dia, doa, dda, dθ =
    numeric_tiso(0.1, 200.0, 0.0, rs, tg, 100000);

spl = Spline1D(dθ, du, k=5);
@show θ0 = fzero(t->evaluate(spl,t)-1.0/R200(0.1,200) , 0.005)
spl = Spline1D(dθ, ddu, k=5);
tgα0 = tan(ray_angle(θ0, R200(0.1,200), evaluate(spl, θ0)))

hx, hy, hu, hdu, hia, hoa, hda, hθ =
    harmonic(0.1, 200.0, θ0, tgα0, 100000);
tx, ty, tu, tdu, tia, toa, tda, tθ =
    thin_tiso(0.1, 200.0, 0.0, rs, tg, 100000);
ex, ey, eu, edu, eia, eoa, eda, eθ =
numeric_tiso_el(0.1, 200.0, 0.0, rs, tg, 100000, reltol=1.0e-14, abstol=1.0e-15);

ix=find(eu.==maximum(eu))[1]
x=ex[ix]
y=ey[ix]
rmin=sqrt(x*x+y*y)

hex, hey, heu, heθ, heia = harmonic_e(0.1, 200.0, rmin, tgα0, 100000);
# Out:
# θ0 = fzero((t->begin  # In[23], line 9:
#                 evaluate(spl,t) - 1.0 / R200(0.1,200)
#             end),0.005) = 0.019507065826707682
# dα = (π / 2 + a1) - a2 = 1.5707969383842695
# dα - π / 2 = 6.115893729230493e-7

# %%
plot(dx/1e3, dy, "-y",lw=3.3)
hold(true)
plot(tx/1e3, ty, "-r",lw=0.9)
plot(ex/1e3, ey, "-g",lw=0.9)
plot(hx/1e3, hy, "-k",lw=0.9)
plot(hex/1e3, hey, ":b",lw=3.5)
legend(["numeric","thin","numeric+el"], loc=3)
grid(true)
xlabel("X [Mpc/h]")
ylabel("Y [Kpc/h]")
r=R200(0.1,200)
x=cos(linspace(0,2π,500)).*r
y=sin(linspace(0,2π,500)).*r
plot(x/1e3,y,"-c")
xlim(-0.3,0.3)
ylim(3.9994,4.00005)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31a3abf50>)
# (3.9994,4.00005)

# %%
plot(dx/1e3, dy, "-y",lw=3.3)
hold(true)
plot(tx/1e3, ty, "-r",lw=0.9)
plot(ex/1e3, ey, "-g",lw=0.9)
plot(hx/1e3, hy, "-k",lw=0.9)
plot(hex/1e3,hey,":b",lw=3.5)
legend(["numeric","thin","numeric+el","harmonic","approx_el"], loc=2)
grid(true)
xlabel("X [Mpc/h]")
ylabel("Y [Kpc/h]")
xlim(-0.07,0.07)
ylim(3.9999,4.00001)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31821e350>)
# (3.9999,4.00001)

# %%
bs=Float64[]
tdas=Float64[]
ddas=Float64[]
edas=Float64[]

rs = 3.3e6
for b in linspace(4, 500, 100)
    push!(bs, b)

    tg = b/rs
    dx, dy, du, ddu, dia, doa, dda, dθ =
        numeric_tiso(0.1, 500.0, 0.0, rs, tg, 100);
    tx, ty, tu, tdu, tia, toa, tda, tθ =
        thin_tiso(0.1, 500.0, 0.0, rs, tg, 100);
    ex, ey, eu, edu, eia, eoa, eda, eθ =
    numeric_tiso_el(0.1, 500.0, 0.0, rs, tg, 100);
    
    push!(tdas, tda)
    push!(ddas, dda)
    push!(edas, eda);
end;

# %%
plot(bs, ddas*1e6, "-y", lw=3.3)
hold(true)
plot(bs, tdas*1e6, "-r", lw=2.1)
plot(bs, edas*1e6, "-g", lw=0.9)
r=R200(0.1,500.0)
plot([r,r],[0,1e7],"--k")
ylim(1e6*minimum(tdas), 1e6*maximum(edas))
grid(true)
xlabel("Impact parameter b [Kpc/h]")
ylabel("Deflection angle x 10^6")
legend(["Numeric","Thin","Numeric+el","halo R"])
title("deflection angles vs impact")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31a168b10>)
# PyObject <matplotlib.text.Text object at 0x31a3b9650>

# %%
t_massfunc(r) = tnfw_m(0.1, 500.0, 50.0, r);
t_rhofunc(r) = tnfw_ρ(0.1, 500.0, 50.0, r);
t_projmass(r) = tnfw_mp(0.1, 500.0, 50.0, r);
l_massfunc(r) = lnfw_m(0.1, 500.0, 50.0, r);
l_rhofunc(r) = lnfw_ρ(0.1, 500.0, 50.0, r);
l_projmass(r) = lnfw_mp(0.1, 500.0, 50.0, r);

# %%
bs=Float64[]

t_nfw_tdas=Float64[]
t_nfw_ddas=Float64[]
t_nfw_edas=Float64[]
l_nfw_tdas=Float64[]
l_nfw_ddas=Float64[]
l_nfw_edas=Float64[]


rs = 3.3e6
for b in linspace(0.001, 350, 200)
    push!(bs, b)

    tg = b/rs
    dx, dy, du, ddu, dia, doa, dda, dθ =
        numeric(t_massfunc, 0.0, rs, tg, 1000);
    tx, ty, tu, tdu, tia, toa, tda, tθ =
        thin(t_projmass, 0.0, rs, tg, 1000);
    ex, ey, eu, edu, eia, eoa, eda, eθ =
        numeric_el(t_massfunc, t_rhofunc, 0.0, rs, tg, 1000);
    
    push!(t_nfw_tdas, float(tda))
    push!(t_nfw_ddas, float(dda))
    push!(t_nfw_edas, float(eda));

    tg = b/rs
    dx, dy, du, ddu, dia, doa, dda, dθ =
        numeric(l_massfunc, 0.0, rs, tg, 1000);
    tx, ty, tu, tdu, tia, toa, tda, tθ =
        thin(l_projmass, 0.0, rs, tg, 1000);
    ex, ey, eu, edu, eia, eoa, eda, eθ =
        numeric_el(l_massfunc, l_rhofunc, 0.0, rs, tg, 1000);
    
    push!(l_nfw_tdas, float(tda))
    push!(l_nfw_ddas, float(dda))
    push!(l_nfw_edas, float(eda));

    
end;

# %%
plot(bs, t_nfw_ddas*1e6, "-y", lw=3.3)
hold(true)
plot(bs, t_nfw_tdas*1e6, "-r", lw=2.1)
plot(bs, t_nfw_edas*1e6, "-g", lw=0.9)

plot(bs, l_nfw_ddas*1e6, "--y", lw=3.3)
plot(bs, l_nfw_tdas*1e6, "--r", lw=2.1)
plot(bs, l_nfw_edas*1e6, "--g", lw=0.9)


r=R200(0.1,500.0)
plot([r,r],[0,1e7],"--k")
plot([13.91,13.91],[0,1e7],"-k")
ylim(1e6*minimum(nfw_tdas), 1e6*maximum(nfw_edas))
grid(true)
xlabel("Impact parameter b [Kpc/h]")
ylabel("Deflection angle x 10^6")
legend(["Numeric","Thin","Numeric+el","halo R", "NFW Rs"])
title("deflection angles vs impact (NFW)")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x322260a10>)
# PyObject <matplotlib.text.Text object at 0x322f75690>

# %%
plot(bs, t_nfw_edas./t_nfw_tdas,"-b")
hold(true)
plot(bs, l_nfw_edas./l_nfw_tdas,"--k")

#plot(bs, nfw_edas./nfw_ddas, "-r")
plot([278,278],[0.8,2.4],"--k")
plot([13.91,13.91],[0.8,2.4],"-k")
grid(true)
xlabel("impact parameter b [Kpc/h]")
ylabel("numerical_el deflection / other deflections")
legend(["thin approximation","numeric, no el","halo R","NFW Rs"], loc=1)
title("ratio of deflection angles vs impact (NFW)")
ylim(1.0, 1.4)
#xlim(0,55)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x3212b1a90>)
# (1.0,1.4)

# %% [markdown]
# # Time

# %%
b = 3.0;
rs = 3.3e6;
tg = b/rs
f = 1.209
up_dx, up_dy, up_du, up_ddu, up_dia, up_doa, up_dda, up_dθ =
    numeric(massfunc, 0.0, rs, tg, 100000);
up_tx, up_ty, up_tu, up_tdu, up_tia, up_toa, up_tda, tθ =
thin(projmass, 0.0, rs*f, tg, 100000);
up_ex, up_ey, up_eu, up_edu, up_eia, up_eoa, up_eda, up_eθ =
    numeric_el(massfunc, rhofunc, 0.0, rs, tg, 100000);

b = 7.0;
rs = 3.3e6;
tg = b/rs
down_dx, down_dy, down_du, down_ddu, down_dia, down_doa, down_dda, down_dθ =
    numeric(massfunc, 0.0, rs, tg, 100000);
down_tx, down_ty, down_tu, down_tdu, down_tia, down_toa, down_tda, down_tθ =
    thin(projmass, 0.0, rs*f, tg, 100000);
down_ex, down_ey, down_eu, down_edu, down_eia, down_eoa, down_eda, down_eθ =
    numeric_el(massfunc, rhofunc, 0.0, rs, tg, 100000);

utx,uty,dtx,dty = extrapolate_to_meeting(up_tx,up_ty,down_tx,down_ty);
udx,udy,ddx,ddy = extrapolate_to_meeting(up_dx,up_dy,down_dx,down_dy);
uex,uey,dex,dey = extrapolate_to_meeting(up_ex,up_ey,down_ex,down_ey);

# %%
hold(false)
plot(utx/1e3,uty,"-r",lw=0.9,label="thin")
hold(true)
plot(dtx/1e3,-dty,"-r",lw=0.9)
#plot(udx/1e3,udy,"-y",lw=0.9)
#plot(ddx/1e3,-ddy,"-y",lw=0.9)
plot(uex/1e3,uey,"-g",lw=0.9, label="numeric+el")
plot(dex/1e3,-dey,"-g",lw=0.9)
plot([0,0],[-8,4],"--k", label="lens plane")
plot([uex[1]/1e3],[uey[1]],"og",label="numeric+el observer")
plot([utx[1]/1e3],[uty[1]],"or",label="thin observer")

plot([uex[end]/1e3],[uey[end]],"*g",ms=7, label="numeric+el source")
plot([utx[end]/1e3],[uty[end]],"*r",ms=7, label="thin source")

hold(false)
grid(true)
xlabel("X [Mpc/h]")
ylabel("Y [Kpc/h]")
#legend(["thin","", "numeric+el","", "lens plane"], loc=3)
legend(loc=3)
title("two configurations satisfying observations (angle+time delay)")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31b83ca10>)
# PyObject <matplotlib.text.Text object at 0x31aa3e750>

# %%
udt = time(massfunc, udx, udy);
ddt = time(massfunc, ddx, ddy);
delta_d = abs(udt-ddt);
utt = time(massfunc, utx, uty);
dtt = time(massfunc, dtx, dty);
delta_t = abs(utt-dtt);
uet = time(massfunc, uex, uey);
det = time(massfunc, dex, dey);
delta_e = abs(uet-det);
@show delta_t;
@show delta_d;
@show delta_e;
# Out:
# delta_t = 6.696865284538944e-11
# delta_d = 4.852651613873604e-11
# delta_e = 6.681588615720102e-11

# %% [markdown]
# # Time 2

# %%
setprecision(128)
b = big"3.0";
rs = big"3.3e6";
tg = b/rs
f = 0.88
up_tx, up_ty, up_tu, up_tdu, up_tia, up_toa, up_tda, tθ =
thin(r->projmass(r)*f, 0.0, rs, tg, 100000);
up_ex, up_ey, up_eu, up_edu, up_eia, up_eoa, up_eda, up_eθ =
    numeric_el(massfunc, rhofunc, 0.0, rs, tg, 100000);

b = big"7.0";
rs = big"3.3e6";
tg = b/rs
down_tx, down_ty, down_tu, down_tdu, down_tia, down_toa, down_tda, down_tθ =
thin(r->projmass(r)*f, 0.0, rs, tg, 100000);
down_ex, down_ey, down_eu, down_edu, down_eia, down_eoa, down_eda, down_eθ =
    numeric_el(massfunc, rhofunc, 0.0, rs, tg, 100000);

# %%
utx,uty,dtx,dty = extrapolate_to_meeting(up_tx,up_ty,down_tx,down_ty);
uex,uey,dex,dey = extrapolate_to_meeting(up_ex,up_ey,down_ex,down_ey);

utt = time(r->massfunc(r)*f, utx, uty);
dtt = time(r->massfunc(r)*f, dtx, dty);
delta_t = abs(utt-dtt);
uet = time(massfunc, uex, uey);
det = time(massfunc, dex, dey);
delta_e = abs(uet-det);
@show delta_t;
@show delta_e;
# Out:
# delta_t = 4.972378064849181e-11
# delta_e = 4.99549596668777677960744805803512317842e-11

# %%
dtx = to_small(dtx)
dty = to_small(dty)
utx = to_small(utx)
uty = to_small(uty)

dex = to_small(dex)
dey = to_small(dey)
uex = to_small(uex)
uey = to_small(uey)

hold(false)
plot(utx/1e3,uty,"-r",lw=0.9,label="thin")
hold(true)
plot(dtx/1e3,-dty,"-r",lw=0.9)
plot(uex/1e3,uey,"-g",lw=0.9, label="numeric+el")
plot(dex/1e3,-dey,"-g",lw=0.9)
plot([0,0],[-8,4],"--k", label="lens plane")
plot([uex[1]/1e3],[uey[1]],"og",label="numeric+el observer")
plot([utx[1]/1e3],[uty[1]],"or",label="thin observer")

plot([uex[end]/1e3],[uey[end]],"*g",ms=7, label="numeric+el source")
plot([utx[end]/1e3],[uty[end]],"*r",ms=7, label="thin source")

hold(false)
grid(true)
xlabel("X [Mpc/h]")
ylabel("Y [Kpc/h]")
#legend(["thin","", "numeric+el","", "lens plane"], loc=3)
legend(loc=3)
title("two configurations satisfying observations (angle+time delay)")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31e1ec190>)
# PyObject <matplotlib.text.Text object at 0x31b6aab90>

# %% [markdown]
# # Precision test

# %%
for prec in [1.0e-8, 1.0e-12, 1.0e-16, 1.0e-20]
    get_delay_hrs(128, big"3.0", big"7.01", big"3.3e6", prec);
    get_delay_hrs(128, big"3.0", big"0.01", big"3.3e6", prec);
end;
# Out:
# "128, 7.009999999999999999999999999999999999992, 9.026794308431694465937683715931632089449e-11"
# "128, 1.000000000000000000000000000000000000001e-02, 1.294067945966521968074101138740261587744e-12"
# "128, 7.009999999999999999999999999999999999992, 9.026794308431694465937683715931632089449e-11"
# "128, 1.000000000000000000000000000000000000001e-02, 1.294067945966521968074101138740261587744e-12"
# "128, 7.009999999999999999999999999999999999992, 9.026794308431694465937683715931632089449e-11"
# "128, 1.000000000000000000000000000000000000001e-02, 1.294067945966521968074101138740261587744e-12"
# "128, 7.009999999999999999999999999999999999992, 9.026794308431694465937683715931632089449e-11"
# "128, 1.000000000000000000000000000000000000001e-02, 1.294067945966521968074101138740261587744e-12"
