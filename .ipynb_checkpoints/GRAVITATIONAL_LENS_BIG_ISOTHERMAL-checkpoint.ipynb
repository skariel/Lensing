# %%
1+1
# Out:
# 2

# %%
include("cosmology.jl")
using PyPlot, ODE, Dierckx, Roots
set_bigfloat_precision(64);

# %%
function _sigrp(rp, R)
    c1 = sqrt(R*R./rp./rp-1.0)
    1./rp.*atan(c1)
end
function _dmdrp(rp, R)
    rp.*_sigrp(rp,R)
end
function _mrp(rp, R)
    quadgk(rp->_dmdrp(rp, R), 0.0, rp)[1]
end
function mrp(M0, R, rp)
    f = M0/_mrp(R, R)
    _mrp(rp, R)*f
end
# Out:
# WARNING: Method definition _sigrp(Any, Any) in module Main at In[8]:2 overwritten at In[10]:2.
# WARNING: Method definition _dmdrp(Any, Any) in module Main at In[8]:6 overwritten at In[10]:6.
# WARNING: Method definition _mrp(Any, Any) in module Main at In[8]:9 overwritten at In[10]:9.
# WARNING: Method definition mrp(Any, Any, Any) in module Main at In[8]:12 overwritten at In[10]:12.
# mrp (generic function with 1 method)

# %%
mrp(200.0, 200.0, 4.0)/4.0
# Out:
# 1.560795992514947

# %%
# Out:
# 0.0

# %%
mrp(199.99, 200.0)
# Out:
# 31415.899869626017

# %%
sigrp(, 200.0)
# Out:
# 0.00031639914322789914

# %%
rg(m) = 2.0.*m.*G./C./C
function miso(M0, r0, r)
    M0.*r./r0
end
rgiso(M0, r0, r) = rg(miso(M0, r0, r))

function direct_lens(M0, r0, b, N=100)
    f=3M0*G/C/C/r0
    ω=sqrt(1.0-f)
    ϕm = 1/ω*acos(b/r0)+π/2
#    ϕl = linspace(ϕm,π-ϕm,N)
    ϕl = linspace(ϕm,π,N)
    
    function f(ϕ, y)
        (u, v) = y
        u_prime = v
        #v_prime = 3/2* frg(1/u) *u*u-u
        v_prime = 3*M0*G/C/C/r0*u-u
        [u_prime; v_prime]    
    end
    const u0 = 1.0/r0    
    const du0 = -ω/b*sin(ω*ϕl[1]-π/2*ω)
    start = [u0; du0];
    
    ϕ, y = ode45(f, start, ϕl, abstol=1.0e-10, reltol=1.0e-12);
    u = map(y -> y[1], y);
    du = map(y -> y[2], y);

    x = [Float64(v) for v in -cos(ϕ)./u]
    y = [Float64(v) for v in sin(ϕ)./u]        
    @show u[end], du[end] 
    x,y, u[end], du[end]
end

function direct_lens3(M0, R, b, u0, du0, N=100)
    ϕl = linspace(0, π, N)    
    function f(ϕ, y)
        (u, v) = y
        u_prime = v
        v_prime = 3*M0*G/C/C/R*u-u
        [u_prime; v_prime]    
    end
    start = [u0; du0];
    
    ϕ, y = ode45(f, start, ϕl, abstol=1.0e-13, reltol=1.0e-14);
    u = map(y -> y[1], y);
    x = [Float64(v) for v in -cos(ϕ)./u]
    y = [Float64(v) for v in sin(ϕ)./u]        
    x,y
end


function analytic_lens(M0, r0, b, N=100)
    @show f=3M0*G/C/C/r0
    ω=sqrt(1.0-f)

    @show ϕm = 1/ω*acos(b/r0)+π/2
    ϕl = linspace(ϕm,π-ϕm,N)
    
    u = 1/b*cos(ω*ϕl-π/2*ω)
    
    x = [Float64(v) for v in cos(ϕl)./u]
    y = [Float64(v) for v in sin(ϕl)./u]        
    x,y
end

function thin_lens(M0p, r0, b, N=100)
    const tgθ = b/r0
    const θ=atan(tgθ)
    #const nθ = θ-2.0*   frg(b)   /b
    const nθ = θ-4*M0p*G/C/C   /b
    const tgnθ = tan(nθ)
    nx = -b/tgnθ
    if nθ>0.0
        nx = r0
    end
    
    lx = linspace(0.0,1.0,div(N,2)).^3
    x = [-reverse(lx)*r0; lx*nx]
    y = zeros(length(x))
    for i in 1:length(x)
        y[i] = if x[i]<0.0
            tgθ*(x[i]+r0)
        else
            b+tgnθ*x[i]
        end
    end
    x = [Float64(xx) for xx in x]
    y = [Float64(yy) for yy in y]
    x, y
end

function mfac(M0, R, rp, N)
    tot = 0.0
    ptot = 0.0
    @inbounds for i in 1:N
        x=rand()*rp+1.0e-5
        y=rand()*rp+1.0e-5
        z=rand()*R+1.0e-5
        r=sqrt(x*x+y*y+z*z)
        r>R && continue
        pr = sqrt(x*x+y*y)
        pr > rp && continue
        ρ=1/r/r
        ptot += ρ
        if r <= rp
            tot += ρ
        end
    end
    ptot/tot
end
# Out:
# mfac (generic function with 1 method)

# %%
# Mmw = big"200.0";
# Rmw = big"200.0";
# b= big"4.0";

Mmw = 200.0;
Rmw = 200.0;
b= 4.0;

# %%
ax,ay = analytic_lens(Mmw, Rmw, b, 170);
# Out:
# f = ((((3M0) * G) / C) / C) / r0 = 1.4355555667711075e-6
# ϕm = (1 / ω) * acos(b / r0) + π / 2 = 3.121592433143794

# %%
dx,dy,u0,du0 = direct_lens(Mmw, Rmw, b, 100000);
dx,dy = direct_lens3(Mmw, Rmw, b, u0, -du0, 100000);
# Out:
# (u[end],du[end]) = (2.8187077756656846e-7,-0.2499998205553308)

# %%
f = mfac(Mmw, Rmw, b, 100000000)
# Out:
# 1.5529592146989297

# %%
M0p = Mmw*b/Rmw*1.560795992514947 #*f
tx,ty = thin_lens(M0p, dx[end], b, 1000);

# %%
hold(false)
plot(dx, dy, "-y", ms=0.0, lw=3.3)
hold(true)
plot(ax, ay, "-k", ms=5.5, lw=1.01)
plot(tx, ty, "-r", ms=5.5, lw=0.71)
plot([-200, -200],[0, 5],"--k")
plot([+200, +200],[0, 5],"--k")
hold(false)
grid(true)
xlim(-300,300)
ylim(3.9994,4.0001)
legend(["Numerical (general)","Exact Analytic (only inside halo)","Thin lens","halo limits"],"bottom left")
xlabel("X [Kpc/h]")
ylabel("Y [Kpc/h]")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x317182490>)
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/legend.py:317: UserWarning: Unrecognized location "bottom left". Falling back on "best"; valid locations are
# 	right
# 	center left
# 	upper right
# 	lower right
# 	best
# 	center
# 	lower left
# 	center right
# 	upper left
# 	upper center
# 	lower center
#
#   % (loc, '\n\t'.join(self.codes.iterkeys())))
# WARNING: Base.writemime is deprecated.
#   likely near /Users/ariel/.julia/v0.5/IJulia/src/kernel.jl:35
# in show at /Users/ariel/.julia/v0.5/PyPlot/src/PyPlot.jl
# PyObject <matplotlib.text.Text object at 0x317280b90>
# WARNING: Base.writemime is deprecated.
#   likely near /Users/ariel/.julia/v0.5/IJulia/src/kernel.jl:35
# WARNING: Base.writemime is deprecated.
#   likely near /Users/ariel/.julia/v0.5/IJulia/src/kernel.jl:35
# WARNING: Base.writemime is deprecated.
#   likely near /Users/ariel/.julia/v0.5/IJulia/src/kernel.jl:35
# WARNING: Base.writemime is deprecated.
#   likely near /Users/ariel/.julia/v0.5/IJulia/src/kernel.jl:35
# WARNING: Base.writemime is deprecated.
#   likely near /Users/ariel/.julia/v0.5/IJulia/src/kernel.jl:35
# WARNING: Base.writemime is deprecated.
#   likely near /Users/ariel/.julia/v0.5/IJulia/src/kernel.jl:35
# WARNING: Base.writemime is deprecated.
#   likely near /Users/ariel/.julia/v0.5/IJulia/src/kernel.jl:35
# WARNING: Base.writemime is deprecated.
#   likely near /Users/ariel/.julia/v0.5/IJulia/src/kernel.jl:35
# WARNING: Base.writemime is deprecated.
#   likely near /Users/ariel/.julia/v0.5/IJulia/src/kernel.jl:35
# WARNING: Base.writemime is deprecated.
#   likely near /Users/ariel/.julia/v0.5/IJulia/src/kernel.jl:35

# %%
hold(false)
plot(dx[1:500:end], dy[1:500:end], "-y", ms=2.5, lw=3.3)
hold(true)
plot(ax, ay, "-k", ms=5.5, lw=1.01)
plot(tx, ty, "-r", ms=5.5, lw=0.71)
plot([-200, -200],[0, 5],"--k")
plot([+200, +200],[0, 5],"--k")
hold(false)
grid(true)
xlim(-5,5)
ylim(3.999994,4.000001)
legend(["Numerical (general)","Exact Analytic (only inside halo)","Thin lens"],"bottom left")
xlabel("X [Kpc/h]")
ylabel("Y [Kpc/h]")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x318339810>)
# PyObject <matplotlib.text.Text object at 0x311d90390>

# %%
hold(false)
plot(dx[1:end]/1e3, dy[1:end], "-y", ms=2.5, lw=3.3)
hold(true)
plot(ax/1e3, ay, "-k", ms=5.5, lw=1.01)
plot(tx/1e3, ty, "-r", ms=5.5, lw=0.71)
plot([-200, -200]/1e3,[0, 5],"--k")
plot([+200, +200]/1e3,[0, 5],"--k")
hold(false)
grid(true)
#xlim(-5,5)
ylim(0,6)
legend(["Numerical (general)","Exact Analytic (only inside halo)","Thin lens","halo limits"],loc=2)
xlabel("X [Mpc/h]")
ylabel("Y [Kpc/h]")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x3172a8690>)
# PyObject <matplotlib.text.Text object at 0x3179cced0>
